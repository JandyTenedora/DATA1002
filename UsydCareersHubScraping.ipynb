# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import pandas as pd
from urllib import urlopen
import re
import numpy as np
from functools import reduce
import os

# %% [markdown]
# Unikey and Password: Recommend using environment variables.
#
# In UNIX-based, we can simply `export UNIKEY=<your unikey>` in this folder.
# Not sure about windows.

# %%
os.environ['UNIKEY'] = "ENTERUNIKEY" 
os.environ['PASS'] = "ENTERPASS"
user = os.environ['UNIKEY']
password = os.environ['PASS']

# %%
driver = webdriver.Chrome()
driver.get("https://careerhub.sydney.edu.au/students/login?ReturnUrl=%2f")

# %%
# Click current student
driver.find_element_by_xpath("/html/body/div[1]/div/div/div/div[2]/div/div[1]/div[1]/a").click()

# Alternatively, if you like html
#driver.find_element_by_css_selector('div.login-service > a').click()

# %%
#identifiying textboxes for login then typing username and password
elem1 = driver.find_element_by_id("userNameInput")
elem1.send_keys(user)

elem2 = driver.find_element_by_id("passwordInput")
elem2.send_keys(password)

#clicking submit
driver.find_element_by_xpath('//*[@id="submitButton"]').click()
time.sleep(2)

# %%
#searching jobs (could add extra search parameters here)
driver.find_element_by_xpath('//*[@id="home-feature"]/div/form/div[1]/div/div[2]/button').click()

# %%
#showing all jobs (dropdown list) -- comment this out for testing since you want to limit jobs
driver.find_element_by_xpath('//*[@id="main"]/div[2]/div/div[3]/div[1]/div[2]/div/div/button').click()
driver.find_element_by_xpath('//*[@id="main"]/div[2]/div/div[3]/div[1]/div[2]/div/div/ul/li[6]/a').click()

# %% [markdown]
# Basically, get the link for each job. Then, we go to each page individually and scrap.

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
base_url = 'https://careerhub.sydney.edu.au'
job_pages = []
#sorting through all the job entries
for tag in soup.find_all("div", {"class": "list-group-item"}):
    #using regular expressions to get rid of tags and unwanted text
    suff = tag.find('a', href = re.compile(r'[/]([a-z]|[A-Z])\w+')).attrs['href'] 
    job_href = 'https://careerhub.sydney.edu.au' + suff
    job_pages.append(job_href)
    
# Alternative way
# job_pages = [base_url + (job.find('a')['href']) for job 
#              in soup.find_all('div', class_='list-group-item')]

# %% [markdown]
# Columns: Title, Company, Location, Description, Type of Work, Contract Type, Contract Hours, Remuneration, etc.
#
# Let's walk through scraping one page.

# %%
sample_page = 'https://careerhub.sydney.edu.au/students/jobs/detail/3382205/graduate-trader'
driver.get(sample_page)

# %%
job_soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# Title, Company, Location(s): They are in `under-nav` class
# Title is h3, Company is h4
# Location(s) inside `p`
container = job_soup.find(class_='under-nav')
title = container.h3.text
company = container.h4.span.text
locations = '#'.join([loc.text.strip() for loc in container.p.find_all('span', class_=None)])

print(title)
print(company)
print(locations)
# Out:
# Graduate Trader
# Maven
# London, United Kingdom#Hong Kong

# %%
# Now, we want the details section and other information.

panels = job_soup.find_all('div', class_='panel-heading')
panels = list(filter(lambda s: s.text in ['Details' , 'Other information'], panels))

DETAILS = 0
INFO = 1

# Panel Content is the next sibling of the header:
# So we do panels.find_next_sibling()

# Our details
description = panels[DETAILS].find_next_sibling().text.strip()

# Other information: This one is a bit tricky since all text blocks are siblings.
# I'm making a dictionary. Key: The header (e.g. Type of Work), Value: The stuff
# The headers are `strong` tags. So we keep getting its siblings until we hit another strong tag.
other_info_dict = {}

for info in panels[INFO].find_next_sibling().find_all('strong'):
    text = []
    # Go to each sibling until next strong
    s = info.find_next_sibling()
    while s != None and s.name != 'strong' and s.name != 'small':
        text.append(s.text)
        s = s.find_next_sibling()
    other_info_dict[info.text] = '#'.join(list(map(lambda s: s.strip(), text)))

# %%
description
# Out:
# u"Maven is looking for outstanding recent graduates or students in their final year of study, to commence as traders in Autumn 2019. You will complete an intensive training program run by experienced traders that will include both classroom sessions and time on the trading floor. You will be executing live trades within three months of commencement, or as soon as you demonstrate the necessary ability in training. You will be responsible for the profit and loss of your book and for managing risk, both individually and as part of a team. You will be encouraged to develop new tools to further the company\u2019s existing trading strategies and to develop new strategies. This is a full-time permanent role and we are recruiting for our London and Hong Kong offices.CANDIDATE SPECIFICATIONS:We are looking for applicants from any quantitative background with a competitive nature, a strong understanding of probability and statistics, and an interest in financial markets. Requirements for eligible candidates:  \u2022\tOutstanding numeracy\u2022\tAttention to detail\u2022\tAbility to solve problems quickly and creatively\u2022\tStrong communication skills\u2022\tA bachelor's degree or higher in a quantitative field (minimum 2.1)Desirable (but not required):\u2022\tFamiliarity with programming languages such as Java, Python, VBA, SQL, R, C++ or C#"

# %%
other_info_dict
# Out:
# {u'Commences': u'September 2019',
#  u'Contract Hours': u'Full Time',
#  u'Contract Type': u'Permanent',
#  u'Remuneration': u'\xa350,000',
#  u'Residency Requirements': u'All candidates considered including international students',
#  u'Type Of Work': u'Graduate Programs#Full Time',
#  u'Website': u'Go to website\n/students/jobs/UrlRedirect/3382205'}

# %% [markdown]
# Note that for the website stuff, the actual `href` is a redirecting url so it's useless.

# %% [markdown]
# ## Let's try get 10 jobs

# %%
samples = job_pages

# %%
# Initial Columns for our dataframe
columns = ['Title', 'Company', 'Location(s)', 'Details']
jobs_df = pd.DataFrame([], columns=columns)
# We don't know how many columns of `other info` so we will wait until we have all of them first.

# %%
error_page = []
DETAILS = 0
INFO = 1
# Keep the other info dictionaries in here to merge later
job_other_info = []
for page in samples:
    driver.get(page)
    time.sleep(2)
    job_soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    try:
        # Job Basic Info
        container = job_soup.find(class_='under-nav')
        title = container.h3.text
        company = container.h4.span.text
        locations = '#'.join([loc.text.strip() for loc in container.p.find_all('span', class_=None)])
        
        # Details
        panels = job_soup.find_all('div', class_='panel-heading')
        panels = list(filter(lambda s: s.text in ['Details' , 'Other information'], panels))
        description = panels[DETAILS].find_next_sibling().text.strip()
        
        jobs_df = jobs_df.append(pd.Series([title, company, locations, description],
                                           index=columns), ignore_index=True)
        
        # Other Info
        other_info_dict = {}
        for info in panels[INFO].find_next_sibling().find_all('strong'):
            text = []
            # Go to each sibling until next strong
            s = info.find_next_sibling()
            while s != None and s.name != 'strong' and s.name != 'small':
                text.append(s.text)
                s = s.find_next_sibling()
            other_info_dict[info.text] = '#'.join(list(map(lambda s: s.strip(), text)))
            
        job_other_info.append(other_info_dict)
    except:
        error_page.append(page)

# %%
# Get all unique headers from `other information`
other_columns = np.unique(reduce(lambda x, y: x + y, map(lambda l: list(l.keys()), job_other_info)))

other_info_df = pd.DataFrame([], columns=other_columns)
for info in job_other_info:
    other_info_df = other_info_df.append(pd.Series(info), ignore_index=True)

# %%
career_df = pd.concat([jobs_df, other_info_df], axis=1)

# %%
career_df
# Out:
#                                                   Title  \
# 0                  IT/Enterprise: Systems Administrator
# 1                Secondary Teacher - Relocate to London
# 2                  Primary Teacher - Relocate to London
# 3                            Practice Area Lead - Legal
# 4     IT Graduate Trainee Programme 2018 - Winter In...
# 5                     PERMANENT OUTBACK VET EXPERIENCE
# 6                         Clubs & Societies Coordinator
# 7     Marketing Officer/Manager Full Time in Sydney ...
# 8                   Business Development Representative
# 9                                         Casual Writer
# 10                        Graduate / Trainee Consultant
# 11                  Casual tutors for Maths and Science
# 12                            Rehabilitation Counsellor
# 13                    PLT Graduate Role/Work Experience
# 14                             Client Intake Supervisor
# 15         Investment Banking Summer Analyst Internship
# 16                             Graduate Physiotherapist
# 17    Recruitment Consultant Trainee (ideally Pharma...
# 18                                 Collections Officers
# 19    Samsung Galaxy Brand Expert– IT & Mobile Commu...
# 20            Tutor in Year 8 Math, Science and English
# 21    Paid: ‘Client Growth Intern’ – Big Data, FMCG ...
# 22                                            Paralegal
# 23                  ABS ICT Vacation Employment Program
# 24                                      English teacher
# 25             Intelligent Process Automation Developer
# 26                            LIVEWORKS 2018 Volunteers
# 27                                   Station Technician
# 28                      Sydney Summer Clerkship Program
# 29                                            Paralegal
# ...                                                 ...
# 1055                                    English Teacher
# 1056                            Youth Program Volunteer
# 1057                             English/Debating Tutor
# 1058                          Casual Child Care Worker
# 1059                Recruitment Consultant - Healthcare
# 1060                                     UI/UX Designer
# 1061                                    Product Manager
# 1062  Front-end/Back-end/Web Crawler/NLP/Machine Lea...
# 1063                Data Scientist/Analyst/Quant/Trader
# 1064  Position: Rental Management Specialist (Full T...
# 1065  1.Position: Property Acquisitions Director/Ass...
# 1066  Position: Client Management Specialist (Part T...
# 1067  2.Position: Short-term Leasing Supervisor (Ful...
# 1068                    Web Developer / Wordpress / PHP
# 1069  Intern Multi Media Marketing Educational Cours...
# 1070               Junior Casual Hospitality Allrounder
# 1071             Behaviour Technicians - ABA Therapists
# 1072                     Japan Ski & Beach Resort Jobs!
# 1073                              Photo Booth Attendant
# 1074                   Indigenous Researcher Internship
# 1075                                     Netball Umpire
# 1076   Casual, Part Time & Full Time Teaching Positions
# 1077              Junior Geophysical Software Developer
# 1078                                   Class Tutor COPY
# 1079                   Live in Carer/UK Working Holiday
# 1080                            Prestige Tuition Tutors
# 1081  The Greenest City in China, ESL&Dancing Teache...
# 1082  Permanent Teaching Jobs - All Sectors, Central...
# 1083    Intern: Data Analytical Research (DAR)/Advisory
# 1084  WANTED: ABA / Occupational / Speech Therapist ...
#
#                                                 Company  \
# 0                                         DE Shaw & CO.
# 1                                Sugarman International
# 2                                Sugarman International
# 3                                   LexisNexis HongKong
# 4                   Cathay Pacific Airways Limited (CX)
# 5                             Redgum Vet & Pet Boarding
# 6                            University of Sydney Union
# 7       Advisory Centre for Australian Education (ACAE)
# 8                                               Insider
# 9                                 Urbanite Technologies
# 10                                 Davidson (Davidson )
# 11                                           Chemtastic
# 1055                        14/1/2018      Part Time     Permanent
# 1056                      Immediately         Casual     Temporary
# 1057                     January 2018         Casual     Temporary
# 1058                        1/01/2018         Casual     Permanent
# 1059                             ASAP      Full Time     Permanent
# 1060                        Immediate      Full Time     Permanent
# 1061                        Immediate      Full Time     Permanent
# 1062                        Immediate      Full Time     Permanent
# 1063                        Immediate      Full Time     Permanent
# 1064                              now      Full Time     Temporary
# 1065                              now      Full Time     Temporary
# 1066                              now      Full Time     Temporary
# 1067                              now      Full Time     Temporary
# 1068                        Immediate      Full Time     Permanent
# 1069                       15 October         Casual     Temporary
# 1070                             ASAP         Casual     Permanent
# 1071                             asap      Full Time     Permanent
# 1072  Positions starting every month!      Full Time     Temporary
# 1073                 1st October 2017         Casual     Permanent
# 1074                         Flexible      Part Time     Temporary
# 1075                           3/8/17         Casual     Temporary
# 1076              Flexible start date         Casual     Temporary
# 1077                         TBD 2018      Full Time     Permanent
# 1078                     15 July 2017         Casual     Temporary
# 1079                           Weekly      Full Time     Temporary
# 1080                             ASAP      Part Time     Permanent
# 1081                            Today      Full Time     Temporary
# 1082    2017 (Term 2, 3 & 4) and 2018      Full Time     Permanent
# 1083              As soon as possible      Part Time     Temporary
# 1084                             ASAP      Part Time     Temporary
#
#        Reference Code                                       Remuneration  \
# 0                 NaN                                                  .
# 1        BRISSEPTDP02                                         £150 a day
# 2        BRISSEPTDP01                                         £150 a day
# 3                 NaN                                         negotiable
# 4                 NaN                                                TBA
# 5                 NaN   start @ $27.50 hr, incremental inc. over 6 mnths
# 6             USU4918                                            $55,000
# 7                 NaN               $42,000 Plus depending on experience
# 8                 NaN                                         60-80K AUD
# 9                 NaN                                       $25 per hour
# 10                NaN                                  $45,000 - $55,000
# 11                NaN                                              25-40
# 12             GradRC                                      Not specified
# 13                NaN                                         Negotiable
# 14                NaN                                              $26/h
# 15                NaN                                        Competitive
# 16                NaN      Above Award package with bonuses over 4 years
# 17                NaN              Competitive base, uncapped commission
# 18                NaN                               $45,000 to $50,000pa
# 19            GBE NSW                                              Award
# 20                NaN                                       $25 per hour
# 21        IRI ACADEMY                                       $25 per hour
# 22                NaN                                       HEO 2 Step 1
# 23    18/ICT_VEP_2018                         $49K (pro-rata) plus super
# 24                NaN                   $60-90ph depending on experience
# 25             IPADEV                           55-65k + Super per annum
# 26                NaN                                          Volunteer
# 27                NaN                                                $25
# 28                NaN                                      $950 per week
# 29                NaN                                             Market
# ...               ...                                                ...
# 1055              NaN                   $3000 to $4000 monthly after tax
# 1056              NaN                                 Volunteer Position
# 1057              NaN                                         Negotiable
# 1058              NaN                                    $24.28 per hour
# 1059              NaN                                            $60,000
# 1060              NaN  dependent on capability, knowledge, and experi...
# 1061              NaN  dependent on capability, knowledge, and experi...
# 1062              NaN  dependent on capability, knowledge, and experi...
# 1063              NaN  dependent on capability, knowledge, and experi...
# 1064              NaN                                          interview
# 1065              NaN                                          interview
# 1066              NaN                                          interview
# 1067              NaN                                          interview
# 1068              NaN                                 Rewarding position
# 1069            media                                             $18-22
# 1070              NaN                             $18 - 25 p/hr (casual)
# 1071           CH0014                       $23-$45 p.h. / 50k+ annually
# 26    Go to website\n/students/jobs/UrlRedirect/3382964
# 27    Go to website\n/students/jobs/UrlRedirect/3382956
# 28    Go to website\n/students/jobs/UrlRedirect/3382418
# 29                                                  NaN
# ...                                                 ...
# 1055                                                NaN
# 1056  Go to website\n/students/jobs/UrlRedirect/2614804
# 1057                                                NaN
# 1058                                                NaN
# 1059  Go to website\n/students/jobs/UrlRedirect/2613721
# 1060  Go to website\n/students/jobs/UrlRedirect/2613647
# 1061  Go to website\n/students/jobs/UrlRedirect/2613646
# 1062  Go to website\n/students/jobs/UrlRedirect/2613645
# 1063  Go to website\n/students/jobs/UrlRedirect/2613644
# 1064                                                NaN
# 1065                                                NaN
# 1066                                                NaN
# 1067                                                NaN
# 1068  Go to website\n/students/jobs/UrlRedirect/2611743
# 1069                                                NaN
# 1070  Go to website\n/students/jobs/UrlRedirect/2611344
# 1071  Go to website\n/students/jobs/UrlRedirect/2610360
# 1072  Go to website\n/students/jobs/UrlRedirect/2124102
# 1073                                                NaN
# 1074  Go to website\n/students/jobs/UrlRedirect/2591535
# 1075                                                NaN
# 1076  Go to website\n/students/jobs/UrlRedirect/2568504
# 1077  Go to website\n/students/jobs/UrlRedirect/2554638
# 1078  Go to website\n/students/jobs/UrlRedirect/2538417
# 1079  Go to website\n/students/jobs/UrlRedirect/2463810
# 1080  Go to website\n/students/jobs/UrlRedirect/2463091
# 1081  Go to website\n/students/jobs/UrlRedirect/2461588
# 1082                                                NaN
# 1083  Go to website\n/students/jobs/UrlRedirect/2452896
# 1084                                                NaN
#
# [1085 rows x 13 columns]

# %%
career_df.to_csv('sample.csv', index=False,encoding="utf-8" )

# %%
read_df = pd.read_csv('sample.csv')

# %%
read_df
# Out:
#                                                   Title  \
# 0                  IT/Enterprise: Systems Administrator
# 1                Secondary Teacher - Relocate to London
# 2                  Primary Teacher - Relocate to London
# 3                            Practice Area Lead - Legal
# 4     IT Graduate Trainee Programme 2018 - Winter In...
# 5                     PERMANENT OUTBACK VET EXPERIENCE
# 6                         Clubs & Societies Coordinator
# 7     Marketing Officer/Manager Full Time in Sydney ...
# 8                   Business Development Representative
# 9                                         Casual Writer
# 10                        Graduate / Trainee Consultant
# 11                  Casual tutors for Maths and Science
# 12                            Rehabilitation Counsellor
# 13                    PLT Graduate Role/Work Experience
# 14                             Client Intake Supervisor
# 15         Investment Banking Summer Analyst Internship
# 16                             Graduate Physiotherapist
# 17    Recruitment Consultant Trainee (ideally Pharma...
# 18                                 Collections Officers
# 19    Samsung Galaxy Brand Expert– IT & Mobile Commu...
# 20            Tutor in Year 8 Math, Science and English
# 21    Paid: ‘Client Growth Intern’ – Big Data, FMCG ...
# 22                                            Paralegal
# 23                  ABS ICT Vacation Employment Program
# 24                                      English teacher
# 25             Intelligent Process Automation Developer
# 26                            LIVEWORKS 2018 Volunteers
# 27                                   Station Technician
# 28                      Sydney Summer Clerkship Program
# 29                                            Paralegal
# ...                                                 ...
# 1055                                    English Teacher
# 1056                            Youth Program Volunteer
# 1057                             English/Debating Tutor
# 1058                          Casual Child Care Worker
# 1059                Recruitment Consultant - Healthcare
# 1060                                     UI/UX Designer
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                NaN
#
#                             Commences Contract Hours Contract Type  \
# 0                                   .      Full Time     Permanent
# 1                        January 2019      Full Time     Temporary
# 2                        January 2019      Full Time     Temporary
# 3                 as soon as possible      Full Time     Permanent
# 4            Late-Feb/ early-Mar 2019      Full Time     Permanent
# 5                          12-11-2018      Full Time     Permanent
# 6                                ASAP      Full Time     Temporary
# 7                       Immiediatelly      Full Time     Permanent
# 8                            Flexible      Full Time     Permanent
# 9                 As soon as possible         Casual     Permanent
# 10                         08/10/2018      Full Time     Permanent
# 11                              01/10         Casual     Permanent
# 12                           Flexible      Full Time     Permanent
# 13                       26-Sept-2018      Full Time     Permanent
# 14                        24-Oct-2018         Casual     Permanent
# 15     Late November / Early December      Full Time     Temporary
# 16                       January 2019      Full Time     Permanent
# 17                               ASAP      Full Time     Permanent
# 18                               asap      Part Time     Permanent
# 19                     3 October 2018         Casual     Temporary
# 20          Week beginning 15 October         Casual     Temporary
# 21                  January 14th 2019      Part Time     Temporary
# 22                         03/12/2018         Casual     Temporary
# 23                  End November 2018      Full Time     Temporary
# 24                           08/10/18         Casual     Permanent
# 25                               asap      Full Time     Temporary
# 26                         18/10/2018         Casual     Temporary
# 27                            October         Casual     Temporary
# 28                   26 November 2018      Full Time     Temporary
# 29                    14 October 2018      Part Time     Permanent
# ...                               ...            ...           ...
# 1055                        14/1/2018      Part Time     Permanent
# 1056                      Immediately         Casual     Temporary
# 1057                     January 2018         Casual     Temporary
# 1058                        1/01/2018         Casual     Permanent
# 1059                             ASAP      Full Time     Permanent
# 1060                        Immediate      Full Time     Permanent
# 1061                        Immediate      Full Time     Permanent
# 1062                        Immediate      Full Time     Permanent
# 1063                        Immediate      Full Time     Permanent
# 1064                              now      Full Time     Temporary
# 1065                              now      Full Time     Temporary
# 1066                              now      Full Time     Temporary
# 1067                              now      Full Time     Temporary
# 1068                        Immediate      Full Time     Permanent
# 1069                       15 October         Casual     Temporary
# 1070                             ASAP         Casual     Permanent
# 1071                             asap      Full Time     Permanent
# 1072  Positions starting every month!      Full Time     Temporary
# 1073                 1st October 2017         Casual     Permanent
# 1074                         Flexible      Part Time     Temporary
# 1075                           3/8/17         Casual     Temporary
# 1076              Flexible start date         Casual     Temporary
# 1077                         TBD 2018      Full Time     Permanent
# 1078                     15 July 2017         Casual     Temporary
# 1079                           Weekly      Full Time     Temporary
# 1080                             ASAP      Part Time     Permanent
# 1081                            Today      Full Time     Temporary
# 1082    2017 (Term 2, 3 & 4) and 2018      Full Time     Permanent
# 1083              As soon as possible      Part Time     Temporary
# 1084                             ASAP      Part Time     Temporary
#
#        Reference Code                                       Remuneration  \
# 0                 NaN                                                  .
# 1        BRISSEPTDP02                                         £150 a day
# 2        BRISSEPTDP01                                         £150 a day
# 3                 NaN                                         negotiable
# 4                 NaN                                                TBA
# 5                 NaN   start @ $27.50 hr, incremental inc. over 6 mnths
# 6             USU4918                                            $55,000
# 7                 NaN               $42,000 Plus depending on experience
# 8                 NaN                                         60-80K AUD
# 9                 NaN                                       $25 per hour
# 10                NaN                                  $45,000 - $55,000
# 11                NaN                                              25-40
# 12             GradRC                                      Not specified
# 13                NaN                                         Negotiable
# 14                NaN                                              $26/h
# 15                NaN                                        Competitive
# 16                NaN      Above Award package with bonuses over 4 years
# 17                NaN              Competitive base, uncapped commission
# 18                NaN                               $45,000 to $50,000pa
# 19            GBE NSW                                              Award
# 20                NaN                                       $25 per hour
# 21        IRI ACADEMY                                       $25 per hour
# 22                NaN                                       HEO 2 Step 1
# 23    18/ICT_VEP_2018                         $49K (pro-rata) plus super
# 24                NaN                   $60-90ph depending on experience
# 25             IPADEV                           55-65k + Super per annum
# 26                NaN                                          Volunteer
# 27                NaN                                                $25
# 28                NaN                                      $950 per week
# 29                NaN                                             Market
# ...               ...                                                ...
# 1055              NaN                   $3000 to $4000 monthly after tax
# 1056              NaN                                 Volunteer Position
# 1057              NaN                                         Negotiable
# 1058              NaN                                    $24.28 per hour
# 1059              NaN                                            $60,000
# 1060              NaN  dependent on capability, knowledge, and experi...
# 1061              NaN  dependent on capability, knowledge, and experi...
# 1062              NaN  dependent on capability, knowledge, and experi...
# 1063              NaN  dependent on capability, knowledge, and experi...
# 1064              NaN                                          interview
# 1065              NaN                                          interview
# 1066              NaN                                          interview
# 1067              NaN                                          interview
# 1068              NaN                                 Rewarding position
# 1069            media                                             $18-22
# 1070              NaN                             $18 - 25 p/hr (casual)
# 1071           CH0014                       $23-$45 p.h. / 50k+ annually
# 1072              NaN  At least 714 yen per hour (minimum wage in Japan)
# 1073              NaN                                           $25/hour
# 1074              NaN       $20 per hour, flexibility in number of hours
# 1075              NaN                        $18/Game (35 minutes games)
# 1076              NaN   Paid to scale - from £130-£160 per day in London
# 1077              NaN                                      70000 - 80000
# 1078            CSR-T                            Depending on experience
# 1079              NaN                  Equivalent to $850 AUD gross/week
# 1080              NaN                                               $20+
# 1081              NaN                                       1800-2400USD
# 1082     CQR2017/2018    Between $58,826 and $88,182 Gross Annual Salary
# 1083              NaN                             Match the market level
# 1084              NaN                             Negotiable hourly rate
#
#                                  Residency Requirements  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     All candidates considered including internatio...
# 5     All candidates considered including internatio...
# 6     All candidates considered including internatio...
# 7     All candidates considered including internatio...
# 8     Australian Citizens and Permanent Residents on...
# 9     All candidates considered including internatio...
# 10    Australian Citizens and Permanent Residents on...
# 11    Australian Citizens and Permanent Residents on...
# 12    Australian Citizens and Permanent Residents on...
# 13    Australian Citizens and Permanent Residents on...
# 14    All candidates considered including internatio...
# 15    Australian Citizens and Permanent Residents on...
# 16                                                  NaN
# 17    Australian Citizens and Permanent Residents on...
# 18    Australian Citizens and Permanent Residents on...
# 19    All candidates considered including internatio...
# 20                                                  NaN
# 21    All candidates considered including internatio...
# 22    All candidates considered including internatio...
# 23                                                  NaN
# 24                                                  NaN
# 25    Australian Citizens and Permanent Residents on...
# 26    All candidates considered including internatio...
# 27    Australian Citizens and Permanent Residents on...
# 28                                                  NaN
# 29    Australian Citizens and Permanent Residents on...
# ...                                                 ...
# 1055  All candidates considered including internatio...
